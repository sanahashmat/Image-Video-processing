# %% [markdown]
# <a href="https://colab.research.google.com/github/sanahashmat/Image-Video-processing/blob/main/contrast_img.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read uploaded image
img = cv2.imread("/content/nature.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# Contrast enhancement using Histogram Equalization
contrast_img = cv2.equalizeHist(gray)

# Display results
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(contrast_img, cmap='gray')
plt.title("Contrast Enhanced Image")
plt.axis("off")

plt.show()
