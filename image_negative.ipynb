# %% [markdown]
# <a href="https://colab.research.google.com/github/sanahashmat/Image-Video-processing/blob/main/image_negative.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program 4: Image Negative Transformation
# Objective: Convert an image into its negative

import cv2
import matplotlib.pyplot as plt

# Load grayscale image
img = cv2.imread('/content/rose flower.jpg', cv2.IMREAD_GRAYSCALE)

# Negative transformation
negative = 255 - img

# Display results
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")

plt.subplot(1,2,2)
plt.imshow(negative, cmap='gray')
plt.title("Negative Image")
plt.show()
