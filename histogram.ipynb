# %% [markdown]
# <a href="https://colab.research.google.com/github/sanahashmat/Image-Video-processing/blob/main/histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#histogram

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read uploaded image
img = cv2.imread("/content/nature.jpg")

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Display image and histogram
plt.figure(figsize=(12,5))

# Grayscale Image
plt.subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")

# Histogram
plt.subplot(1,2,2)
plt.hist(gray.ravel(), bins=256, range=[0,256])
plt.title("Histogram of Grayscale Image")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")

plt.show()
