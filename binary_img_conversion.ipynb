# %% [markdown]
# <a href="https://colab.research.google.com/github/sanahashmat/Image-Video-processing/blob/main/binary_img_conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program 5: Binary Image Conversion
# Objective: Convert a grayscale image into a binary image using thresholding

import cv2
import matplotlib.pyplot as plt

# Load grayscale image
img = cv2.imread('/content/nature.jpg', cv2.IMREAD_GRAYSCALE)

# Apply threshold
_, binary = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)

# Display results
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("Grayscale Image")

plt.subplot(1,2,2)
plt.imshow(binary, cmap='gray')
plt.title("Binary Image")
plt.show()
